# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/eventbrite.csv")

# %%
df.head()
# Out:
#                                                event           event_date  \
# 0                Good practices in research software  2018-09-18T09:30:00
# 1                             FAIR Software Workshop  2020-09-08T09:00:00
# 2  Version Control and Collaboration with Git and...  2017-09-06T09:30:00
# 3  Version Control and Collaboration with Git and...  2018-04-19T09:30:00
# 4               ePLAN workshop Computational Science  2019-03-28T12:00:00
#
#    year org_id               name                      email      affiliation  \
# 0  2018  NLeSc       Bradley Hong         zhangel109@163.com              NaN
# 1  2020  NLeSc    Ashutosh Pandey  anshuashutosh24@gmail.com  AIIMS RISHIKESH
# 2  2017  NLeSc       Paul de Heer            p.deheer@amc.nl    UMC Amsterdam
# 3  2018  NLeSc     Simona Aufiero       s.aufiero@amc.uva.nl              UvA
# 4  2019  ePlan  Cristoforo Grasso        c.grasso@amc.uva.nl              UvA
#
#      Affiliation_type              car1 car2  ...               created  \
# 0                 NaN               NaN  NaN  ...  2018-08-20T20:48:58Z
# 1  Research institute  Graduate Student  NaN  ...  2020-08-29T07:35:18Z
# 2                 NaN               NaN  NaN  ...  2017-08-07T09:47:21Z
# 3                 NaN               NaN  NaN  ...  2018-04-16T10:44:27Z
# 4                 NaN               NaN  NaN  ...  2019-03-22T08:37:32Z
#
#                                           event_type event_level  \
# 0                Good practices in research software   Essential
# 1                             FAIR Software Workshop   Essential
# 2  Version Control and Collaboration with Git and...   Essential
# 3  Version Control and Collaboration with Git and...   Essential
# 4               ePLAN workshop Computational Science   Essential
#
#                              event_focus                      ticket_type  \
# 0                                  Other        Partners on JCER projects
# 1                                  Other                General Admission
# 2  Open & Reproducible Research Software                          Regular
# 3  Open & Reproducible Research Software  eScience Center project members
# 4                                  Other                   General ticket
#
#      order_id          id      event_id    venue_id  \
# 0   811374812  1010663759   48161580584  25760598.0
# 1  1436867271  2005660371  116114017151         NaN
# 2   655803000   820703592   35234474261  19932187.0
# 3   758303450   945046865   42978307274  23542290.0
# 4   920465851  1154583459   55700229887  29201345.0
#
#                                                  uri
# 0  https://www.eventbriteapi.com/v3/events/481615...
# 1  https://www.eventbriteapi.com/v3/events/116114...
# 2  https://www.eventbriteapi.com/v3/events/352344...
# 3  https://www.eventbriteapi.com/v3/events/429783...
# 4  https://www.eventbriteapi.com/v3/events/557002...
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   event             742 non-null    object
#  1   event_date        742 non-null    object
#  2   year              742 non-null    int64
#  3   org_id            742 non-null    object
#  4   name              742 non-null    object
#  5   email             742 non-null    object
#  6   affiliation       559 non-null    object
#  7   Affiliation_type  16 non-null     object
#  8   car1              246 non-null    object
#  9   car2              31 non-null     object
#  10  eSc_collab        226 non-null    object
#  11  ERCdis            317 non-null    object
#  12  NLeScdis          317 non-null    object
#  13  dis1              338 non-null    object
#  14  dis2              134 non-null    object
#  15  dis3              66 non-null     object
#  16  dis4              30 non-null     object
#  17  dis5              9 non-null      object
#  18  aff_country       16 non-null     object
#  19  RI_type           6 non-null      object
#  20  created           742 non-null    object
#  21  event_type        742 non-null    object
#  22  event_level       742 non-null    object
#  23  event_focus       742 non-null    object
#  24  ticket_type       742 non-null    object
#  25  order_id          742 non-null    int64
#  26  id                742 non-null    object
#  27  event_id          742 non-null    int64
#  28  venue_id          374 non-null    float64
#  29  uri               742 non-null    object
# dtypes: float64(1), int64(3), object(26)
# memory usage: 174.0+ KB

# %% [markdown]
# ## Bar charts

# %%
# Define function for bar plot

def barplot(df, x_column, y_column):
    sns.set()
    sns.set_style('white')
    f, ax = plt.subplots(figsize=(10,6))
    sns.barplot(x=x_column, y=y_column, data=df, color='deepskyblue')
    ax.tick_params(axis='both', which='major', labelsize=14)
    plt.xlabel(x_column, fontsize=16)
    plt.ylabel(y_column, fontsize=16)
    plt.suptitle(y_column + ' by ' + x_column, fontsize=18)
    sns.despine()
    
    return plt.show()

# %% [markdown]
# #### Participants by year

# %%
# Create df with participants by year
df_participants_by_year = df.groupby('year').agg({'order_id': 'count'}).reset_index()
df_participants_by_year.rename(columns = {'order_id': 'participants'}, inplace = True)
df_participants_by_year.head()
# Out:
#    year  participants
# 0  2015             6
# 1  2016            50
# 2  2017           182
# 3  2018            67
# 4  2019            69

# %%
# plot participants by year
barplot(df_participants_by_year, 'year', 'participants')

# %%
# TO DO: make these plots for different types of events (add column)

# %% [markdown]
# #### Participants by disciplinary section

# %%
# Create df with participants by section

df_participants_by_section = df.groupby('NLeScdis').agg({'NLeScdis': 'count'}).reset_index()
#df_participants_by_section.rename(columns = {'NLeScdis': 'NLeSc_section'}, inplace = True)
df_participants_by_section.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-868124547af7> in <module>
#       1 # Create df with participants by section
#       2
# ----> 3 df_participants_by_section = df.groupby('NLeScdis').agg({'NLeScdis': 'count'}).reset_index()
#       4 #df_participants_by_section.rename(columns = {'NLeScdis': 'NLeSc_section'}, inplace = True)
#       5 df_participants_by_section.head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5014                 # to ndarray and maybe infer different dtype
#    5015                 level_values = maybe_casted_values(lev, lab)
# -> 5016                 new_obj.insert(0, name, level_values)
#    5017
#    5018         new_obj.index = new_index
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# -> 1191             raise ValueError(f"cannot insert {item}, already exists")
#    1192
#    1193         if not isinstance(loc, int):
#
# ValueError: cannot insert NLeScdis, already exists
